# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /opt/conda/lib/python3.9/site-packages (24.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fosforml
# Out:
# Requirement already satisfied: fosforml in /opt/conda/lib/python3.9/site-packages (1.1.8)
# Requirement already satisfied: cloudpickle==2.2.1 in /opt/conda/lib/python3.9/site-packages (from fosforml) (2.2.1)
# Requirement already satisfied: scikit-learn==1.3.2 in /opt/conda/lib/python3.9/site-packages (from fosforml) (1.3.2)
# Requirement already satisfied: snowflake-ml-python==1.5.0 in /opt/conda/lib/python3.9/site-packages (from fosforml) (1.5.0)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /opt/conda/lib/python3.9/site-packages (from scikit-learn==1.3.2->fosforml) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn==1.3.2->fosforml) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.9/site-packages (from scikit-learn==1.3.2->fosforml) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn==1.3.2->fosforml) (3.5.0)
# Requirement already satisfied: absl-py<2,>=0.15 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0->fosforml) (1.4.0)
# Requirement already satisfied: anyio<4,>=3.5.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0->fosforml) (3.7.1)
# Requirement already satisfied: cachetools<6,>=3.1.1 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0->fosforml) (5.5.0)
# Requirement already satisfied: catboost<1.3,>=1.2.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0->fosforml) (1.2.7)
# Requirement already satisfied: fsspec<2024,>=2022.11 in /opt/conda/lib/python3.9/site-packages (from fsspec[http]<2024,>=2022.11->snowflake-ml-python==1.5.0->fosforml) (2023.12.2)
# Requirement already satisfied: importlib-resources<7,>=6.1.1 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0->fosforml) (6.4.5)
# Requirement already satisfied: packaging<24,>=20.9 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0->fosforml) (23.2)
# Requirement already satisfied: pandas<3,>=1.0.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0->fosforml) (2.2.0)
# Requirement already satisfied: pyarrow in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0->fosforml) (18.1.0)
# Requirement already satisfied: pytimeparse<2,>=1.1.8 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0->fosforml) (1.1.8)
# Requirement already satisfied: pyyaml<7,>=6.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0->fosforml) (6.0.1)
# Requirement already satisfied: retrying<2,>=1.3.3 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0->fosforml) (1.3.4)
# Requirement already satisfied: s3fs<2024,>=2022.11 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0->fosforml) (2023.12.2)
# Requirement already satisfied: snowflake-connector-python<4,>=3.5.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python==1.5.0->fosforml) (3.12.4)
# Requirement already satisfied: snowflake-snowpark-python!=1.12.0,<2,>=1.11.1 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0->fosforml) (1.26.0)
# Requirement already satisfied: sqlparse<1,>=0.4 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0->fosforml) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.1.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0->fosforml) (4.12.2)
# Requirement already satisfied: xgboost<2,>=1.7.3 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0->fosforml) (1.7.6)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.9/site-packages (from anyio<4,>=3.5.0->snowflake-ml-python==1.5.0->fosforml) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.9/site-packages (from anyio<4,>=3.5.0->snowflake-ml-python==1.5.0->fosforml) (1.3.1)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.9/site-packages (from anyio<4,>=3.5.0->snowflake-ml-python==1.5.0->fosforml) (1.2.2)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.9/site-packages (from catboost<1.3,>=1.2.0->snowflake-ml-python==1.5.0->fosforml) (0.20.3)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.9/site-packages (from catboost<1.3,>=1.2.0->snowflake-ml-python==1.5.0->fosforml) (3.9.4)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.9/site-packages (from catboost<1.3,>=1.2.0->snowflake-ml-python==1.5.0->fosforml) (5.24.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from catboost<1.3,>=1.2.0->snowflake-ml-python==1.5.0->fosforml) (1.16.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from fsspec[http]<2024,>=2022.11->snowflake-ml-python==1.5.0->fosforml) (2.32.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.9/site-packages (from fsspec[http]<2024,>=2022.11->snowflake-ml-python==1.5.0->fosforml) (3.11.10)
# Requirement already satisfied: zipp>=3.1.0 in /opt/conda/lib/python3.9/site-packages (from importlib-resources<7,>=6.1.1->snowflake-ml-python==1.5.0->fosforml) (3.19.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.9/site-packages (from pandas<3,>=1.0.0->snowflake-ml-python==1.5.0->fosforml) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas<3,>=1.0.0->snowflake-ml-python==1.5.0->fosforml) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.9/site-packages (from pandas<3,>=1.0.0->snowflake-ml-python==1.5.0->fosforml) (2024.1)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /opt/conda/lib/python3.9/site-packages (from s3fs<2024,>=2022.11->snowflake-ml-python==1.5.0->fosforml) (2.15.2)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python==1.5.0->fosforml) (1.5.1)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python==1.5.0->fosforml) (1.16.0)
# Requirement already satisfied: cryptography>=3.1.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python==1.5.0->fosforml) (42.0.5)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=22.0.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python==1.5.0->fosforml) (24.0.0)
# Requirement already satisfied: pyjwt<3.0.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python==1.5.0->fosforml) (2.10.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python==1.5.0->fosforml) (3.3.2)
# Requirement already satisfied: urllib3<2.0.0,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python==1.5.0->fosforml) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python==1.5.0->fosforml) (2024.7.4)
# Requirement already satisfied: filelock<4,>=3.5 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python==1.5.0->fosforml) (3.16.1)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python==1.5.0->fosforml) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python==1.5.0->fosforml) (4.2.2)
# Requirement already satisfied: tomlkit in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python==1.5.0->fosforml) (0.13.2)
# Requirement already satisfied: setuptools>=40.6.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-snowpark-python!=1.12.0,<2,>=1.11.1->snowflake-ml-python==1.5.0->fosforml) (65.6.3)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.9/site-packages (from snowflake-snowpark-python!=1.12.0,<2,>=1.11.1->snowflake-ml-python==1.5.0->fosforml) (0.37.1)
# Requirement already satisfied: protobuf<6,>=3.20 in /opt/conda/lib/python3.9/site-packages (from snowflake-snowpark-python!=1.12.0,<2,>=1.11.1->snowflake-ml-python==1.5.0->fosforml) (5.29.1)
# Requirement already satisfied: tzlocal in /opt/conda/lib/python3.9/site-packages (from snowflake-snowpark-python!=1.12.0,<2,>=1.11.1->snowflake-ml-python==1.5.0->fosforml) (5.2)
# Requirement already satisfied: botocore<1.35.37,>=1.35.16 in /opt/conda/lib/python3.9/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs<2024,>=2022.11->snowflake-ml-python==1.5.0->fosforml) (1.35.36)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /opt/conda/lib/python3.9/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs<2024,>=2022.11->snowflake-ml-python==1.5.0->fosforml) (1.17.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /opt/conda/lib/python3.9/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs<2024,>=2022.11->snowflake-ml-python==1.5.0->fosforml) (0.12.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2024,>=2022.11->snowflake-ml-python==1.5.0->fosforml) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2024,>=2022.11->snowflake-ml-python==1.5.0->fosforml) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2024,>=2022.11->snowflake-ml-python==1.5.0->fosforml) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2024,>=2022.11->snowflake-ml-python==1.5.0->fosforml) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2024,>=2022.11->snowflake-ml-python==1.5.0->fosforml) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2024,>=2022.11->snowflake-ml-python==1.5.0->fosforml) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2024,>=2022.11->snowflake-ml-python==1.5.0->fosforml) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2024,>=2022.11->snowflake-ml-python==1.5.0->fosforml) (1.18.3)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.9/site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python==1.5.0->fosforml) (2.21)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->catboost<1.3,>=1.2.0->snowflake-ml-python==1.5.0->fosforml) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib->catboost<1.3,>=1.2.0->snowflake-ml-python==1.5.0->fosforml) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib->catboost<1.3,>=1.2.0->snowflake-ml-python==1.5.0->fosforml) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->catboost<1.3,>=1.2.0->snowflake-ml-python==1.5.0->fosforml) (1.4.7)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.9/site-packages (from matplotlib->catboost<1.3,>=1.2.0->snowflake-ml-python==1.5.0->fosforml) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->catboost<1.3,>=1.2.0->snowflake-ml-python==1.5.0->fosforml) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.9/site-packages (from plotly->catboost<1.3,>=1.2.0->snowflake-ml-python==1.5.0->fosforml) (9.0.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.9/site-packages (from botocore<1.35.37,>=1.35.16->aiobotocore<3.0.0,>=2.5.4->s3fs<2024,>=2022.11->snowflake-ml-python==1.5.0->fosforml) (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from fosforml.model_manager.snowflakesession import get_session
my_session = get_session()
table_name = 'DATAANALYSISFINAL24'
sf_df = my_session.sql("select * from {}".format(table_name))
df = sf_df.to_pandas()

# %%
pip install fbprophet
# Out:
# Collecting fbprophet
#   Using cached fbprophet-0.7.1.tar.gz (64 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Cython>=0.22 in /opt/conda/lib/python3.9/site-packages (from fbprophet) (3.0.11)
# Collecting cmdstanpy==0.9.5 (from fbprophet)
#   Using cached cmdstanpy-0.9.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: pystan>=2.14 in /opt/conda/lib/python3.9/site-packages (from fbprophet) (3.9.1)
# Requirement already satisfied: numpy>=1.15.4 in /opt/conda/lib/python3.9/site-packages (from fbprophet) (1.26.4)
# Requirement already satisfied: pandas>=1.0.4 in /opt/conda/lib/python3.9/site-packages (from fbprophet) (2.2.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from fbprophet) (3.9.4)
# Collecting LunarCalendar>=0.0.9 (from fbprophet)
#   Using cached LunarCalendar-0.0.9-py2.py3-none-any.whl.metadata (6.3 kB)
# Collecting convertdate>=2.1.2 (from fbprophet)
#   Using cached convertdate-2.4.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: holidays>=0.10.2 in /opt/conda/lib/python3.9/site-packages (from fbprophet) (0.63)
# Collecting setuptools-git>=1.2 (from fbprophet)
#   Using cached setuptools_git-1.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.9/site-packages (from fbprophet) (2.9.0.post0)
# Requirement already satisfied: tqdm>=4.36.1 in /opt/conda/lib/python3.9/site-packages (from fbprophet) (4.66.4)
# Collecting pymeeus<=1,>=0.3.13 (from convertdate>=2.1.2->fbprophet)
#   Using cached PyMeeus-0.5.12-py3-none-any.whl
# Collecting ephem>=3.7.5.3 (from LunarCalendar>=0.0.9->fbprophet)
#   Using cached ephem-4.1.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.0 kB)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.9/site-packages (from LunarCalendar>=0.0.9->fbprophet) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.0.0->fbprophet) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.0.0->fbprophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.0.0->fbprophet) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.0.0->fbprophet) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.0.0->fbprophet) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.0.0->fbprophet) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.0.0->fbprophet) (3.2.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.0.0->fbprophet) (6.4.5)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.0.4->fbprophet) (2024.1)
# Requirement already satisfied: aiohttp<4.0,>=3.6 in /opt/conda/lib/python3.9/site-packages (from pystan>=2.14->fbprophet) (3.11.10)
# Requirement already satisfied: clikit<0.7,>=0.6 in /opt/conda/lib/python3.9/site-packages (from pystan>=2.14->fbprophet) (0.6.2)
# Requirement already satisfied: httpstan<4.13,>=4.12 in /opt/conda/lib/python3.9/site-packages (from pystan>=2.14->fbprophet) (4.12.0)
# Requirement already satisfied: pysimdjson<7,>=5.0.2 in /opt/conda/lib/python3.9/site-packages (from pystan>=2.14->fbprophet) (6.0.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from pystan>=2.14->fbprophet) (65.6.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.8.0->fbprophet) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.9/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.9/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.9/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (1.18.3)
# Requirement already satisfied: crashtest<0.4.0,>=0.3.0 in /opt/conda/lib/python3.9/site-packages (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet) (0.3.1)
# Requirement already satisfied: pastel<0.3.0,>=0.2.0 in /opt/conda/lib/python3.9/site-packages (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet) (0.2.1)
# Requirement already satisfied: pylev<2.0,>=1.3 in /opt/conda/lib/python3.9/site-packages (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet) (1.4.0)
# Requirement already satisfied: appdirs<2.0,>=1.4 in /opt/conda/lib/python3.9/site-packages (from httpstan<4.13,>=4.12->pystan>=2.14->fbprophet) (1.4.4)
# Requirement already satisfied: marshmallow<4.0,>=3.10 in /opt/conda/lib/python3.9/site-packages (from httpstan<4.13,>=4.12->pystan>=2.14->fbprophet) (3.23.2)
# Requirement already satisfied: webargs<9.0,>=8.0 in /opt/conda/lib/python3.9/site-packages (from httpstan<4.13,>=4.12->pystan>=2.14->fbprophet) (8.6.0)
# Requirement already satisfied: zipp>=3.1.0 in /opt/conda/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=2.0.0->fbprophet) (3.19.2)
# Requirement already satisfied: typing-extensions>=4.1.0 in /opt/conda/lib/python3.9/site-packages (from multidict<7.0,>=4.5->aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (4.12.2)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.9/site-packages (from yarl<2.0,>=1.17.0->aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (3.7)
# Using cached cmdstanpy-0.9.5-py3-none-any.whl (37 kB)
# Using cached convertdate-2.4.0-py3-none-any.whl (47 kB)
# Using cached LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Using cached setuptools_git-1.2-py2.py3-none-any.whl (10 kB)
# Using cached ephem-4.1.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
# Building wheels for collected packages: fbprophet
#   Building wheel for fbprophet (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [53 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib
#       creating build/lib/fbprophet
#       creating build/lib/fbprophet/stan_model
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-o485xg44/fbprophet_61cf12d2fb1e4e8ba6ed29bf7a7587db/setup.py", line 122, in <module>
#           setup(
#         File "/opt/conda/lib/python3.9/site-packages/setuptools/__init__.py", line 87, in setup
#           return distutils.core.setup(**attrs)
#         File "/opt/conda/lib/python3.9/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#         File "/opt/conda/lib/python3.9/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/opt/conda/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "/opt/conda/lib/python3.9/site-packages/setuptools/dist.py", line 1208, in run_command
#           super().run_command(command)
#         File "/opt/conda/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/opt/conda/lib/python3.9/site-packages/wheel/bdist_wheel.py", line 299, in run
#           self.run_command('build')
#         File "/opt/conda/lib/python3.9/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/opt/conda/lib/python3.9/site-packages/setuptools/dist.py", line 1208, in run_command
#           super().run_command(command)
#         File "/opt/conda/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/opt/conda/lib/python3.9/site-packages/setuptools/_distutils/command/build.py", line 132, in run
#           self.run_command(cmd_name)
#         File "/opt/conda/lib/python3.9/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/opt/conda/lib/python3.9/site-packages/setuptools/dist.py", line 1208, in run_command
#           super().run_command(command)
#         File "/opt/conda/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/tmp/pip-install-o485xg44/fbprophet_61cf12d2fb1e4e8ba6ed29bf7a7587db/setup.py", line 48, in run
#           build_models(target_dir)
#         File "/tmp/pip-install-o485xg44/fbprophet_61cf12d2fb1e4e8ba6ed29bf7a7587db/setup.py", line 36, in build_models
#           from fbprophet.models import StanBackendEnum
#         File "/tmp/pip-install-o485xg44/fbprophet_61cf12d2fb1e4e8ba6ed29bf7a7587db/fbprophet/__init__.py", line 8, in <module>
#           from fbprophet.forecaster import Prophet
#         File "/tmp/pip-install-o485xg44/fbprophet_61cf12d2fb1e4e8ba6ed29bf7a7587db/fbprophet/forecaster.py", line 17, in <module>
#           from fbprophet.make_holidays import get_holiday_names, make_holidays_df
#         File "/tmp/pip-install-o485xg44/fbprophet_61cf12d2fb1e4e8ba6ed29bf7a7587db/fbprophet/make_holidays.py", line 14, in <module>
#           import fbprophet.hdays as hdays_part2
#         File "/tmp/pip-install-o485xg44/fbprophet_61cf12d2fb1e4e8ba6ed29bf7a7587db/fbprophet/hdays.py", line 13, in <module>
#           from convertdate.islamic import from_gregorian, to_gregorian
#       ModuleNotFoundError: No module named 'convertdate'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for fbprophet
#   Running setup.py clean for fbprophet
# Failed to build fbprophet
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (fbprophet)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /opt/conda/lib/python3.9/site-packages (24.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cython numpy pystan
# Out:
# Requirement already satisfied: cython in /opt/conda/lib/python3.9/site-packages (3.0.11)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.9/site-packages (1.26.4)
# Requirement already satisfied: pystan in /opt/conda/lib/python3.9/site-packages (3.9.1)
# Requirement already satisfied: aiohttp<4.0,>=3.6 in /opt/conda/lib/python3.9/site-packages (from pystan) (3.11.10)
# Requirement already satisfied: clikit<0.7,>=0.6 in /opt/conda/lib/python3.9/site-packages (from pystan) (0.6.2)
# Requirement already satisfied: httpstan<4.13,>=4.12 in /opt/conda/lib/python3.9/site-packages (from pystan) (4.12.0)
# Requirement already satisfied: pysimdjson<7,>=5.0.2 in /opt/conda/lib/python3.9/site-packages (from pystan) (6.0.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from pystan) (65.6.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp<4.0,>=3.6->pystan) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.9/site-packages (from aiohttp<4.0,>=3.6->pystan) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp<4.0,>=3.6->pystan) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp<4.0,>=3.6->pystan) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.9/site-packages (from aiohttp<4.0,>=3.6->pystan) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.9/site-packages (from aiohttp<4.0,>=3.6->pystan) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp<4.0,>=3.6->pystan) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp<4.0,>=3.6->pystan) (1.18.3)
# Requirement already satisfied: crashtest<0.4.0,>=0.3.0 in /opt/conda/lib/python3.9/site-packages (from clikit<0.7,>=0.6->pystan) (0.3.1)
# Requirement already satisfied: pastel<0.3.0,>=0.2.0 in /opt/conda/lib/python3.9/site-packages (from clikit<0.7,>=0.6->pystan) (0.2.1)
# Requirement already satisfied: pylev<2.0,>=1.3 in /opt/conda/lib/python3.9/site-packages (from clikit<0.7,>=0.6->pystan) (1.4.0)
# Requirement already satisfied: appdirs<2.0,>=1.4 in /opt/conda/lib/python3.9/site-packages (from httpstan<4.13,>=4.12->pystan) (1.4.4)
# Requirement already satisfied: marshmallow<4.0,>=3.10 in /opt/conda/lib/python3.9/site-packages (from httpstan<4.13,>=4.12->pystan) (3.23.2)
# Requirement already satisfied: webargs<9.0,>=8.0 in /opt/conda/lib/python3.9/site-packages (from httpstan<4.13,>=4.12->pystan) (8.6.0)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.9/site-packages (from marshmallow<4.0,>=3.10->httpstan<4.13,>=4.12->pystan) (23.2)
# Requirement already satisfied: typing-extensions>=4.1.0 in /opt/conda/lib/python3.9/site-packages (from multidict<7.0,>=4.5->aiohttp<4.0,>=3.6->pystan) (4.12.2)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.9/site-packages (from yarl<2.0,>=1.17.0->aiohttp<4.0,>=3.6->pystan) (3.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install prophet
# Out:
# Requirement already satisfied: prophet in /opt/conda/lib/python3.9/site-packages (1.1.6)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /opt/conda/lib/python3.9/site-packages (from prophet) (1.2.5)
# Requirement already satisfied: numpy>=1.15.4 in /opt/conda/lib/python3.9/site-packages (from prophet) (1.26.4)
# Requirement already satisfied: matplotlib>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from prophet) (3.9.4)
# Requirement already satisfied: pandas>=1.0.4 in /opt/conda/lib/python3.9/site-packages (from prophet) (2.2.0)
# Requirement already satisfied: holidays<1,>=0.25 in /opt/conda/lib/python3.9/site-packages (from prophet) (0.63)
# Requirement already satisfied: tqdm>=4.36.1 in /opt/conda/lib/python3.9/site-packages (from prophet) (4.66.4)
# Requirement already satisfied: importlib-resources in /opt/conda/lib/python3.9/site-packages (from prophet) (6.4.5)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /opt/conda/lib/python3.9/site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.9/site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (3.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /opt/conda/lib/python3.9/site-packages (from importlib-resources->prophet) (3.19.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.0.4->prophet) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.0.4->prophet) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16784 entries, 0 to 16783
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATE           16784 non-null  object
#  1   DRUG_ID        16784 non-null  object
#  2   CUSTOMER_NAME  16784 non-null  object
#  3   VOLUME         16784 non-null  float64
#  4   UNIT_PRICE     16784 non-null  int16
#  5   TOTAL          16784 non-null  float64
#  6   Discount%      16784 non-null  int8
#  7   CUSTOMER       16784 non-null  object
#  8   CITY           16784 non-null  object
#  9   REGION         16784 non-null  object
#  10  COUNTRY        16784 non-null  object
#  11  NAME           16784 non-null  object
#  12  SEGMENT        16784 non-null  object
# dtypes: float64(2), int16(1), int8(1), object(9)
# memory usage: 1.5+ MB

# %%
df.head()
# Out:
#          DATE DRUG_ID CUSTOMER_NAME  VOLUME  UNIT_PRICE   TOTAL  Discount%  \
# 0  2014-01-02  Drug 1          CS56    0.00         500     0.0          5
# 1  2014-01-02  Drug 2          CS48    3.67          70   256.9          7
# 2  2014-01-02  Drug 3          CS78    3.40          20    68.0          5
# 3  2014-01-02  Drug 4          CS02   32.40          14   453.6          7
# 4  2014-01-02  Drug 5          CS56    7.00        1200  8400.0          3
#
#      CUSTOMER     CITY           REGION    COUNTRY      NAME  \
# 0  Dr Reddy's   Sydney     Asia-Pacific  Australia  anx 10mg
# 1      Pfizer  Toronto    North America     Canada  anx 50mg
# 2         GSK     Oslo  Northern Europe     Norway  and 15mg
# 3         GSK     Pune       South Asia      India  and 20mg
# 4  Dr Reddy's   Sydney     Asia-Pacific  Australia  anp 30mg
#
#              SEGMENT
# 0        Antianxiety
# 1        Antianxiety
# 2      Antidiarrheal
# 3      Antidiarrheal
# 4  Antihypertensives

# %%
df.describe(include='all').T
# Out:
#                  count unique            top  freq        mean          std  \
# DATE             16784   2098     2019-09-30     8         NaN          NaN
# DRUG_ID          16784     10         Drug 8  2052         NaN          NaN
# CUSTOMER_NAME    16784     80           CS19   248         NaN          NaN
# VOLUME         16784.0    NaN            NaN   NaN    7.569952    10.891197
# UNIT_PRICE     16784.0    NaN            NaN   NaN      236.25   395.678867
# TOTAL          16784.0    NaN            NaN   NaN  1756.27928  4210.381013
# Discount%      16784.0    NaN            NaN   NaN    6.259354     2.572202
# CUSTOMER         16784      8         Pfizer  2197         NaN          NaN
# CITY             16784     10           Oslo  1748         NaN          NaN
# REGION           16784      7  North America  3445         NaN          NaN
# COUNTRY          16784      9          India  3278         NaN          NaN
# NAME             16784      9       and 20mg  3732         NaN          NaN
# SEGMENT          16784      5  Antihistamine  3730         NaN          NaN
#
#                min     25%    50%    75%      max
# DATE           NaN     NaN    NaN    NaN      NaN
# DRUG_ID        NaN     NaN    NaN    NaN      NaN
# CUSTOMER_NAME  NaN     NaN    NaN    NaN      NaN
# VOLUME         0.0  1.8675    4.0    8.0    161.0
# UNIT_PRICE     6.0    18.5   40.0  177.5   1200.0
# TOTAL          0.0    40.0  150.0  722.4  66000.0
# Discount%      3.0     5.0    7.0    7.0     10.0
# CUSTOMER       NaN     NaN    NaN    NaN      NaN
# CITY           NaN     NaN    NaN    NaN      NaN
# REGION         NaN     NaN    NaN    NaN      NaN
# COUNTRY        NaN     NaN    NaN    NaN      NaN
# NAME           NaN     NaN    NaN    NaN      NaN
# SEGMENT        NaN     NaN    NaN    NaN      NaN
